# %% [markdown]
# <a href="https://colab.research.google.com/github/XingxinHE/Python-for-Data-Analysis-Notes/blob/master/11_3_Date_Ranges%2C_Frequencies%2C_and_Shifting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Generating Date Ranges

# %%
#以起始日，结束日 生成Date Range
index = pd.date_range('2012-04-01', '2012-06-01')
index #下面的freq='D'代表以天为间隔的意思
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
# ...

# %%
#以起始日，时间段 生成Date Range
pd.date_range(start='2012-04-01', periods=20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
#以结束日，时间段 生成Date Range
pd.date_range(end='2012-06-01', periods=20)
# Out:
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
#这个🐂🍺，时间段只算一个月最后的工作日有效
pd.date_range('2000-01-01', '2000-12-01', freq='BM') #BM=business month
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30'],
#               dtype='datetime64[ns]', freq='BM')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Frequencies and Date Offsets

# %% [markdown]
# 时间间隔用M,D,H ， 月，日，时

# %%
#以4小时为间隔
pd.date_range('2000-01-01', '2000-01-03 23:59', freq='4h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
#以1个半小时为间隔
pd.date_range('2000-01-01', periods=10, freq='1h30min')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90T')

# %% [markdown]
# ### Week of month dates

# %% [markdown]
# WOM= week of month dates, 例如每个月的第三个星期五

# %%
rng = pd.date_range('2012-01-01', '2012-09-01', freq='WOM-3FRI')
rng
# Out:
# DatetimeIndex(['2012-01-20', '2012-02-17', '2012-03-16', '2012-04-20',
#                '2012-05-18', '2012-06-15', '2012-07-20', '2012-08-17'],
#               dtype='datetime64[ns]', freq='WOM-3FRI')

# %% [markdown]
# ## Shifting(Leading and Lagging) Data

# %%
ts = pd.Series(np.random.randn(4), index=pd.date_range('1/1/2000', periods=4, freq='M'))

# %%
ts
# Out:
# 2000-01-31   -0.503343
# 2000-02-29   -1.510508
# 2000-03-31    0.902630
# 2000-04-30   -0.733056
# Freq: M, dtype: float64

# %%
ts.shift(2) #这和premier的滚轴很像，往前挪
# Out:
# 2000-01-31         NaN
# 2000-02-29         NaN
# 2000-03-31   -0.503343
# 2000-04-30   -1.510508
# Freq: M, dtype: float64

# %%
ts.shift(-2) #这和premier的滚轴很像，往后退
# Out:
# 2000-01-31    0.902630
# 2000-02-29   -0.733056
# 2000-03-31         NaN
# 2000-04-30         NaN
# Freq: M, dtype: float64

# %% [markdown]
# 上面的shift没有指定shift哪里，所以是移动数据。只要用freq来specify，就不会shift数据，而是shift timestamp

# %%
ts.shift(2, freq='M') #指定是shift月份，那么数据则不会变，变的是index
# Out:
# 2000-03-31   -0.503343
# 2000-04-30   -1.510508
# 2000-05-31    0.902630
# 2000-06-30   -0.733056
# Freq: M, dtype: float64

# %%
ts.shift(3, freq='D') #shift天
# Out:
# 2000-02-03   -0.503343
# 2000-03-03   -1.510508
# 2000-04-03    0.902630
# 2000-05-03   -0.733056
# dtype: float64

# %%
ts.shift(1, freq='90T') #这里的T是分钟，即shift90分钟
# Out:
# 2000-01-31 01:30:00   -0.503343
# 2000-02-29 01:30:00   -1.510508
# 2000-03-31 01:30:00    0.902630
# 2000-04-30 01:30:00   -0.733056
# Freq: M, dtype: float64

# %% [markdown]
# ### Shifting data with offsets

# %% [markdown]
# 有没有一种方法是能像加减乘除一样对时间进行移动？
#
# 如下

# %%
from pandas.tseries.offsets import Day, MonthEnd

# %%
now = datetime(2011, 11, 17)

# %%
now + 3*Day() #往now推三天
# Out:
# Timestamp('2011-11-20 00:00:00')

# %%
now + MonthEnd() #往now推到下个月末的工作日
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
now + MonthEnd() #往now推到2个月末的工作日
# Out:
# Timestamp('2011-11-30 00:00:00')

# %% [markdown]
# 还有一种叫做roll的方法

# %%
offset = MonthEnd()

# %%
offset.rollforward(now) #now往前roll到最近的月末工作日
# Out:
# Timestamp('2011-11-30 00:00:00')

# %%
offset.rollback(now) #now往后roll到最近的月末工作日
# Out:
# Timestamp('2011-10-31 00:00:00')

# %% [markdown]
# 其实这种roll的方法和groupby搭配最为🐂🍺

# %%
ts = pd.Series(np.random.randn(20), index=pd.date_range('1/15/2000', periods=20, freq='4d'))
ts
# Out:
# 2000-01-15    1.999925
# 2000-01-19    0.525664
# 2000-01-23    0.838427
# 2000-01-27   -0.699532
# 2000-01-31    0.322585
# 2000-02-04   -1.309951
# 2000-02-08   -1.187900
# 2000-02-12   -1.093224
# 2000-02-16    2.108826
# 2000-02-20    0.065635
# 2000-02-24   -2.306611
# 2000-02-28    1.116963
# 2000-03-03    0.236100
# 2000-03-07   -0.541923
# 2000-03-11   -0.528434
# 2000-03-15    0.999966
# 2000-03-19   -1.892828
# 2000-03-23    0.747884
# 2000-03-27   -0.785247
# 2000-03-31    0.656764
# Freq: 4D, dtype: float64

# %%
#就是把每个index都弄成月末工作日，那就会出现下面的三组，
#然后根据这三组取mean
ts.groupby(offset.rollforward).mean()
# Out:
# 2000-01-31    0.597414
# 2000-02-29   -0.372323
# 2000-03-31   -0.138465
# dtype: float64

# %%
#但其实，这种严格意义来说是resample，本来时间维度是天，现在取为月，pandas有更加直观的做法：
ts.resample('M').mean()
# Out:
# 2000-01-31    0.597414
# 2000-02-29   -0.372323
# 2000-03-31   -0.138465
# Freq: M, dtype: float64
